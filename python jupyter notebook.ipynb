# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b> Name = Shayan Bhowmick </b> <br>Current Occupation = Software Engineer

# %% [markdown]
# *I am interested in data science because it will enable me to use the large data sets that are generated each and every seconds which will help me and my organization to use the data and get proper insights which will help in the growth of various business organizations.*

# %% [markdown]
# ### Its a normal addition code in cell 5

# %%
5+10
# Out:
# 15

# %% [markdown]
# ### Main programming languages used in data sciences are:
# 1. R
# 2. Python
# ***
# <br>[My github account](https://github.com/ShayanBhowmick)
